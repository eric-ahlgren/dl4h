# %%
import os
import sys
import pickle
import psutil
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split

# Define data path
DATA_PATH = "data/"
CHECKPOINT_PATH = "models/"

# %%
pids = pickle.load(open(os.path.join(DATA_PATH,'pids.pkl'), 'rb'))
vids = pickle.load(open(os.path.join(DATA_PATH,'vids.pkl'), 'rb'))
targs = pickle.load(open(os.path.join(DATA_PATH,'targets.pkl'), 'rb'))
prob_targs = pickle.load(open(os.path.join(DATA_PATH, 'prob_targets_allvisits.pkl'), 'rb'))
seqs = pickle.load(open(os.path.join(DATA_PATH,'seqs.pkl'), 'rb'))
diags = pickle.load(open(os.path.join(DATA_PATH,'diags.pkl'), 'rb'))
codes = pickle.load(open(os.path.join(DATA_PATH,'icd9.pkl'), 'rb'))
categories = pickle.load(open(os.path.join(DATA_PATH,'categories.pkl'), 'rb'))
sub_categories = pickle.load(open(os.path.join(DATA_PATH,'subcategories.pkl'), 'rb'))
assert len(pids) == len(vids) == len(targs) == len(seqs)

# %%
embedding_matrix = torch.load(os.path.join(DATA_PATH, 'embedding_matrix.pt'))

# %%
class CustomDataset(Dataset):
    
    def __init__(self, seqs, targets):
        self.x = seqs
        self.y = targets
    
    def __len__(self): 
        return(len(self.x))
    
    def __getitem__(self, index):
        return (self.x[index], self.y[index])

# %%
# dataset = CustomDataset(seqs, targs)
dataset = CustomDataset(seqs, prob_targs)

# %%
def collate_fn(data):
    """
    Arguments:
        data: a list of samples fetched from `CustomDataset`
        
    Outputs:
        x: a tensor of shape (# patiens, max # visits, max # diagnosis codes) of type torch.long
        x_masks: a tensor of shape (# patiens, max # visits, max # diagnosis codes) of type torch.bool
        rev_x: same as x but in reversed time.
        rev_masks: same as x_masks but in reversed time.
        y: a tensor of shape (# patients, max # diagnosis categories) of type torch.float
        y_masks: a tensor of shape (# patients, max # diagnosis categories) of type torch.bool
    """
#     sequences, targets = zip(*data)

#     num_patients = len(sequences)
#     num_visits = [len(patient) for patient in sequences]
#     num_codes = [len(visit) for patient in sequences for visit in patient]
#     batch_num_categories = [len(visit) for patient in targets for visit in patient]

#     max_num_visits = max(num_visits)
#     max_num_codes = max(num_codes)
#     max_num_categories = max(batch_num_categories)
    
#     x = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.long)
#     y = torch.zeros((num_patients, max_num_categories), dtype=torch.long)
#     rev_x = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.long)
#     x_masks = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.bool)
#     rev_x_masks = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.bool)
#     y_masks = torch.zeros((num_patients, max_num_categories), dtype=torch.bool)
#     for i_patient, patient in enumerate(sequences):   
#         for j_visit, visit in enumerate(patient[:-1]):
#             for k_code, code in enumerate(visit):
#                 x[i_patient, j_visit, k_code] = code
#                 x_masks[i_patient, j_visit, k_code] = 1
#                 if j_visit == len(patient) - 2 and k_code == len(visit) - 1:
#                     rev_visit = x_masks[i_patient].any(dim=1)
#                     rev_x[i_patient, rev_visit] = x[i_patient, rev_visit].flip(0)
#                     rev_x_masks[i_patient, rev_visit] = x_masks[i_patient, rev_visit].flip(0)
                
#     for i_patient, patient in enumerate(targets):   
#         for visit in patient[-1:]:
#             for k_code, code in enumerate(visit):
#                 y[i_patient, k_code] = code
#                 y_masks[i_patient, k_code] = 1
    
#     return x, x_masks, rev_x, rev_x_masks, y, y_masks

    sequences, targets = zip(*data)

    num_patients = len(sequences)
    num_visits = [len(patient) for patient in sequences]
    num_codes = [len(visit) for patient in sequences for visit in patient]
    batch_num_categories = [len(visit) for patient in targets for visit in patient]
    max_num_visits = max(num_visits)
    max_num_codes = max(num_codes)
#     max_num_categories = max(batch_num_categories)
    max_num_categories = len(targets[0][0])
    
    x = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.long)
    rev_x = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.long)
    x_masks = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.bool)
    rev_x_masks = torch.zeros((num_patients, max_num_visits, max_num_codes), dtype=torch.bool)
#     y = torch.zeros((num_patients, max_num_categories), dtype=torch.long)
    y = torch.zeros((num_patients, max_num_categories), dtype=torch.float)
    y_masks = torch.zeros((num_patients, max_num_categories), dtype=torch.bool)
    for i_patient, patient in enumerate(sequences):   
        for j_visit, visit in enumerate(patient[:-1]):
            for k_code, code in enumerate(visit):
                x[i_patient, j_visit, k_code] = code
                x_masks[i_patient, j_visit, k_code] = 1
                if j_visit == len(patient) - 2 and k_code == len(visit) - 1:
                    rev_visit = x_masks[i_patient].any(dim=1)
                    rev_x[i_patient, rev_visit] = x[i_patient, rev_visit].flip(0)
                    rev_x_masks[i_patient, rev_visit] = x_masks[i_patient, rev_visit].flip(0)

#     for i_patient, patient in enumerate(targets):
# #         import pdb; pdb.set_trace()
#         last_visit = patient[-1]
#         y[i_patient,:len(last_visit)] = torch.LongTensor(last_visit)
#         y_masks[i_patient,:len(last_visit)] = torch.BoolTensor(np.ones(len(last_visit)))
    for i_patient, patient in enumerate(targets):
#         import pdb; pdb.set_trace()
        last_visit = patient[-1]
        y[i_patient] = torch.FloatTensor(last_visit)
        y_masks[i_patient] = torch.BoolTensor(np.ones(max_num_categories))
    
    return x, x_masks, rev_x, rev_x_masks, y, y_masks

# %%
train_split = int(len(dataset)*0.75)
test_split = int(len(dataset)*0.15)
val_split = int(len(dataset)*0.10)

# %%
train_split = int(len(dataset)*0.75)
test_split = int(len(dataset)*0.15)

lengths = [train_split, test_split, len(dataset) - (train_split + test_split)]
train_dataset, test_dataset, val_dataset = random_split(dataset, lengths)

print("Length of train dataset:", len(train_dataset))
print("Length of test dataset:", len(test_dataset))
print("Length of val dataset:", len(val_dataset))
# Out:
# Length of train dataset: 6561
# Length of test dataset: 1312
# Length of val dataset: 875

# %%
def load_data(train_dataset, test_dataset, val_dataset, collate_fn):
    '''
    Arguments:
        train dataset: train dataset of type `CustomDataset`
        test dataset: test dataset of type `CustomDataset`
        val dataset: validation dataset of type `CustomDataset`
        collate_fn: collate function
        
    Outputs:
        train_loader, test_loader, val_loader: train, test and validation dataloaders
    '''
    batch_size = 100
    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=batch_size,
                                               collate_fn=collate_fn,
                                               shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_dataset,
                                           batch_size=batch_size,
                                           collate_fn=collate_fn,
                                           shuffle=False)
    val_loader = torch.utils.data.DataLoader(val_dataset,
                                             batch_size=batch_size,
                                             collate_fn=collate_fn,
                                             shuffle=False)
    
    return train_loader, test_loader, val_loader


train_loader, test_loader, val_loader = load_data(train_dataset, test_dataset, val_dataset, collate_fn)

# %%
def sum_embeddings_with_mask(x, masks):
    """
    Arguments:
        x: the embeddings of diagnosis sequence of shape (batch_size, # visits, # diagnosis codes, embedding_dim)
        masks: the padding masks of shape (batch_size, # visits, # diagnosis codes)

    Outputs:
        sum_embeddings: the sum of embeddings of shape (batch_size, # visits, embedding_dim)
    """
    x[~masks] = 0
    return x.sum(2)

# %%
def attention_sum(alpha, beta, rev_v, rev_masks):
    """
    Arguments:
        alpha: the alpha attention weights of shape (batch_size, # visits, 1)
        beta: the beta attention weights of shape (batch_size, # visits, hidden_dim)
        rev_v: the visit embeddings in reversed time of shape (batch_size, # visits, embedding_dim)
        rev_masks: the padding masks in reversed time of shape (batch_size, # visits, # diagnosis codes)

    Outputs:
        c: the context vector of shape (batch_size, hidden_dim)
    """
    rev_masks = rev_masks[:,:].any(dim=2)
    rev_v_masked = rev_v.clone()
    rev_v_masked[~rev_masks] = 0
    weights = alpha * beta
    a_sum = torch.sum(weights * rev_v_masked, dim=1)
    return a_sum

# %%
class AlphaAttention(torch.nn.Module):

    def __init__(self, hidden_dim):
        super().__init__()
        """ 
        Arguments:
            hidden_dim: the hidden dimension
        """
        
        self.a_att = nn.Linear(hidden_dim, 1)

    def forward(self, g):
        """
        Arguments:
            g: the output tensor from RNN-alpha of shape (batch_size, # visits, hidden_dim) 
        
        Outputs:
            alpha: the corresponding attention weights of shape (batch_size, # visits, 1)
        """
        m = nn.Softmax(dim=1)
        return m(self.a_att(g))

# %%
class BetaAttention(torch.nn.Module):

    def __init__(self, hidden_dim):
        super().__init__()
        """
        Arguments:
            hidden_dim: the hidden dimension
        """
        
        self.b_att = nn.Linear(hidden_dim, hidden_dim)


    def forward(self, h):
        """
        Arguments:
            h: the output tensor from RNN-beta of shape (batch_size, # visits, hidden_dim) 
        
        Outputs:
            beta: the corresponding attention weights of shape (batch_size, # visits, hidden_dim)
        """
        return torch.tanh(self.b_att(h))

# %%
class EnhancedRETAIN(nn.Module):
    
    def __init__(self, num_codes, num_categories):
        super().__init__()
        """
        Arguments:
            num_codes: total number of diagnosis codes
            num_categories: total number of diagnosis categories to predict
        """
        self.embedding = nn.Linear(num_codes, 300)
        self.embedding.weight.data = embedding_matrix
        self.rnn_a = nn.GRU(300, hidden_size=128, batch_first=True)
        self.rnn_b = nn.GRU(300, hidden_size=128, batch_first=True)
        self.att_a = AlphaAttention(128)
        self.att_b = AlphaAttention(128)
        self.fc = nn.Linear(300, num_categories)
    
    def forward(self, x, masks, rev_x, rev_masks):
        """
        Arguments:
            x: the diagnosis sequence of shape (batch_size, # visits, # diagnosis codes)
            masks: the padding masks of shape (batch_size, # visits, # diagnosis codes)
            rev_x: the diagnosis sequence of shape (batch_size, # visits, # diagnosis codes)
            rev_masks: the padding masks of shape (batch_size, # visits, # diagnosis codes)

        Outputs:
            logits: logits of shape (batch_size, # categories)
        """
        rev_x = indices_to_multihot(rev_x, rev_masks, 4903)
        rev_x = self.embedding(rev_x)
        rev_x[~rev_masks.any(dim=2)] = 0  # Set masked visits to 0
        g, _ = self.rnn_a(rev_x)
        h, _ = self.rnn_b(rev_x)
        alpha = self.att_a(g)
        beta = self.att_b(h)
        c = attention_sum(alpha, beta, rev_x, rev_masks)
        logits = self.fc(c)
        return logits

# load the model here
enhanced_retain = EnhancedRETAIN(num_codes = len(codes), num_categories=len(sub_categories))
enhanced_retain
# Out:
# EnhancedRETAIN(
#   (embedding): Linear(in_features=4903, out_features=300, bias=True)
#   (rnn_a): GRU(300, 128, batch_first=True)
#   (rnn_b): GRU(300, 128, batch_first=True)
#   (att_a): AlphaAttention(
#     (a_att): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (att_b): AlphaAttention(
#     (a_att): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (fc): Linear(in_features=300, out_features=184, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.Adam(naive_rnn.parameters(), lr=0.001)
optimizer = torch.optim.Adadelta(enhanced_retain.parameters(), weight_decay=0.001)

# %%
def train(model, train_loader, test_loader, n_epochs):
    """
    Arguments:
        model: the EnhancedRETAIN model
        train_loader: training dataloder
        test_loader: validation dataloader
        n_epochs: total number of epochs
    """
#     max_cpu, max_ram = print_cpu_usage()
#     for epoch in range(n_epochs):
#         model.train()
#         train_loss = 0
#         for x, x_masks, rev_x, rev_x_masks, y, y_masks in train_loader:
#             y_hat = model(x, x_masks, rev_x, rev_x_masks) 
#             y_mh = indices_to_multihot(y, y_masks, y_hat.shape[-1])
#             loss = criterion(y_hat, y_mh)
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()
#             train_loss += loss.item()
#         train_loss = train_loss / len(train_loader)
#         cpu, ram = print_cpu_usage()
#         max_cpu = cpu if cpu > max_cpu else max_cpu
#         max_ram = ram if ram > max_ram else max_ram
#         print(f'Epoch: {epoch+1} \t Training Loss: {train_loss:.6f}')
#         for k in range(5, 31, 5):
#             precision_k, accuracy_k = eval_model(model, test_loader, k=k)
#             print(f'Epoch: {epoch+1} \t Validation precision@k{k}: {precision_k:.4f}, accuracy@k{k}: {accuracy_k:.4f}')
#     final_cpu, final_ram = print_cpu_usage()
#     print(f"Max CPU usage: {max_cpu:.3f}\tMax RAM % usage: {max_ram}")

    max_cpu, max_ram = print_cpu_usage()
    for epoch in range(n_epochs):
        model.train()
        train_loss = 0
        for x, x_masks, rev_x, rev_x_masks, y, y_masks in train_loader:
            y_hat = model(x, x_masks, rev_x, rev_x_masks)                  
#             y_mh = indices_to_multihot(y, y_masks, y_hat)
            loss = criterion(y_hat, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss = train_loss / len(train_loader)
        cpu, ram = print_cpu_usage()
        max_cpu = cpu if cpu > max_cpu else max_cpu
        max_ram = ram if ram > max_ram else max_ram
        print(f'Epoch: {epoch+1} \t Training Loss: {train_loss:.6f}')
        for k in range(5, 31, 5):
            precision_k, accuracy_k = eval_model(model, val_loader, k=k)
            print(f'Epoch: {epoch+1} \t Validation precision@k{k}: {precision_k:.4f}, accuracy@k{k}: {accuracy_k:.4f}')
    final_cpu, final_ram = print_cpu_usage()
    print(f"Max CPU usage: {max_cpu:.3f}\tMax RAM % usage: {max_ram}")

# %%
def eval_model(model, test_loader, k=15, n=-1):
    """
    Arguments:
        model: the EnhancedRETAIN model
        test_loader: validation dataloader
        k: value for top k predictions
        n: num of records to evaluate in the batch, value -1 evaulates all records
        
    Outputs:
        precision_k: visit-level precison@k
        accuracy_k: code-level accuracy@k
    """
#     y_pred = torch.LongTensor()
#     y_true = torch.LongTensor()
#     all_precision = []
#     all_accuracy = []
    
#     model.eval()
#     with torch.no_grad():
#         for x, x_masks, rev_x, rev_x_masks, y, y_masks in test_loader:
#             n_eval = y.shape[0] - 1 if n == -1 else n
#             y_hat = model(x, x_masks, rev_x, rev_x_masks)
#             y_hat = F.softmax(y_hat, dim=-1)
#             y_multihot = indices_to_multihot(y, y_masks, y_hat.shape[-1])
#             k_correct = 0
#             total_precision = 0
#             total_accuracy = 0
#             for i in range(n_eval):
#                 visit_correct = 0
#                 y_true = y[i, y_masks[i]]
#                 _, y_pred = torch.topk(y_hat[i], k)

#                 for v in y_true:
#                     if v in y_pred:
#                         visit_correct += 1
                        
#                 visit_precision = visit_correct / min(k, len(y_true))
#                 visit_accuracy = visit_correct / len(y_true)
#                 k_correct += visit_correct
#                 total_precision += visit_precision
#                 total_accuracy += visit_accuracy

#             precision_k = total_precision / n_eval
#             accuracy_k = total_accuracy / n_eval
#             all_precision.append(precision_k)
#             all_accuracy.append(accuracy_k)

#     total_precision_k = np.mean(all_precision)
#     total_accuracy_k = np.mean(all_accuracy)
#     return total_precision_k, total_accuracy_k

    y_pred = torch.LongTensor()
    y_true = torch.LongTensor()
    all_precision = []
    all_accuracy = []
    
    model.eval()
    with torch.no_grad():
        for x, x_masks, rev_x, rev_x_masks, y, y_masks in test_loader:
            n_eval = y.shape[0] - 1 if n == -1 else n
            y_hat = model(x, x_masks, rev_x, rev_x_masks)
            y_hat = F.softmax(y_hat, dim=-1)
            #y_multihot = indices_to_multihot(y, y_masks, y_hat)
            nz_rows, nz_cols = torch.nonzero(y, as_tuple=True)
            k_correct = 0
            total_precision = 0
            total_accuracy = 0
            for i in range(n_eval):
                visit_correct = 0
                #y_true = y[i, y_masks[i]]
                y_true = nz_cols[nz_rows == i]
                _, y_pred = torch.topk(y_hat[i], k)
                for v in y_true:
                    if v in y_pred:
                        visit_correct += 1
                visit_precision = visit_correct / min(k, len(y_true))
                visit_accuracy = visit_correct / len(y_true)
                k_correct += visit_correct
                total_precision += visit_precision
                total_accuracy += visit_accuracy
            precision_k = total_precision / n_eval
            accuracy_k = total_accuracy / n_eval
            all_precision.append(precision_k)
            all_accuracy.append(accuracy_k)
            
    total_precision_k = np.mean(all_precision)
    total_accuracy_k = np.mean(all_accuracy)
    return total_precision_k, total_accuracy_k

# %%
def indices_to_multihot(indices, masks, dim):
    mh_size = tuple(indices.shape[:-1]) + (dim,)
    multihot = torch.zeros(mh_size, dtype=torch.float)
    if len(mh_size) == 3:
        for i, patient in enumerate(indices):
            for j, visit in enumerate(patient):
                if masks[i,j].sum() == 0:
                    break
                y_idx = visit[masks[i,j]].unique()
                multihot[i,j] = F.one_hot(y_idx.to(torch.int64), multihot.shape[-1]).sum(0)
    else:
        for idx, row in enumerate(indices):
            y_idx = row[masks[idx]].unique()
            multihot[idx] = F.one_hot(y_idx, dim).sum(0).float()
    return multihot

# %%
def print_cpu_usage():
    load = psutil.getloadavg()[2]
    cpu_usage = (load/os.cpu_count()) * 100
    ram = psutil.virtual_memory()[2]
    print(f"CPU: {cpu_usage:0.2f}")
    print(f"RAM %: {ram}")
    return cpu_usage, ram

# %%
n_epochs = 100
# %time train(enhanced_retain, train_loader, val_loader, n_epochs)
# Out:
# CPU: 15.82
# RAM %: 61.4
# CPU: 15.90
# RAM %: 61.9
# Epoch: 1 	 Training Loss: 4.313518
# Epoch: 1 	 Validation precision@k5: 0.4301, accuracy@k5: 0.2212
# Epoch: 1 	 Validation precision@k10: 0.4155, accuracy@k10: 0.3537
# Epoch: 1 	 Validation precision@k15: 0.4788, accuracy@k15: 0.4651
# Epoch: 1 	 Validation precision@k20: 0.5684, accuracy@k20: 0.5670
# Epoch: 1 	 Validation precision@k25: 0.6451, accuracy@k25: 0.6450
# Epoch: 1 	 Validation precision@k30: 0.7171, accuracy@k30: 0.7171
# CPU: 15.92
# RAM %: 61.9
# Epoch: 2 	 Training Loss: 4.065195
# Epoch: 2 	 Validation precision@k5: 0.5084, accuracy@k5: 0.2672
# Epoch: 2 	 Validation precision@k10: 0.4983, accuracy@k10: 0.4269
# Epoch: 2 	 Validation precision@k15: 0.5555, accuracy@k15: 0.5401
# Epoch: 2 	 Validation precision@k20: 0.6267, accuracy@k20: 0.6251
# Epoch: 2 	 Validation precision@k25: 0.7006, accuracy@k25: 0.7005
# Epoch: 2 	 Validation precision@k30: 0.7666, accuracy@k30: 0.7666
# CPU: 15.91
# RAM %: 61.8
# Epoch: 3 	 Training Loss: 3.974746
# Epoch: 3 	 Validation precision@k5: 0.6016, accuracy@k5: 0.3184
# Epoch: 3 	 Validation precision@k10: 0.5650, accuracy@k10: 0.4857
# Epoch: 3 	 Validation precision@k15: 0.6151, accuracy@k15: 0.5985
# Epoch: 3 	 Validation precision@k20: 0.6838, accuracy@k20: 0.6821
# Epoch: 3 	 Validation precision@k25: 0.7412, accuracy@k25: 0.7411
# Epoch: 3 	 Validation precision@k30: 0.7884, accuracy@k30: 0.7884
# CPU: 16.17
# RAM %: 61.9
# Epoch: 4 	 Training Loss: 3.908630
# Epoch: 4 	 Validation precision@k5: 0.5455, accuracy@k5: 0.2916
# Epoch: 4 	 Validation precision@k10: 0.5377, accuracy@k10: 0.4630
# Epoch: 4 	 Validation precision@k15: 0.6008, accuracy@k15: 0.5846
# Epoch: 4 	 Validation precision@k20: 0.6787, accuracy@k20: 0.6771
# Epoch: 4 	 Validation precision@k25: 0.7412, accuracy@k25: 0.7411
# Epoch: 4 	 Validation precision@k30: 0.7926, accuracy@k30: 0.7926
# CPU: 16.11
# RAM %: 61.8
# Epoch: 5 	 Training Loss: 3.864558
# Epoch: 5 	 Validation precision@k5: 0.5249, accuracy@k5: 0.2852
# Epoch: 5 	 Validation precision@k10: 0.4910, accuracy@k10: 0.4261
# Epoch: 5 	 Validation precision@k15: 0.5446, accuracy@k15: 0.5307
# Epoch: 5 	 Validation precision@k20: 0.6151, accuracy@k20: 0.6137
# Epoch: 5 	 Validation precision@k25: 0.6800, accuracy@k25: 0.6799
# Epoch: 5 	 Validation precision@k30: 0.7348, accuracy@k30: 0.7348
# CPU: 16.22
# RAM %: 61.8
# Epoch: 6 	 Training Loss: 3.788769
# Epoch: 6 	 Validation precision@k5: 0.6261, accuracy@k5: 0.3345
# Epoch: 6 	 Validation precision@k10: 0.5890, accuracy@k10: 0.5088
# Epoch: 6 	 Validation precision@k15: 0.6307, accuracy@k15: 0.6137
# Epoch: 6 	 Validation precision@k20: 0.6960, accuracy@k20: 0.6943
# Epoch: 6 	 Validation precision@k25: 0.7547, accuracy@k25: 0.7546
# Epoch: 6 	 Validation precision@k30: 0.8067, accuracy@k30: 0.8067
# CPU: 16.49
# RAM %: 61.9
# Epoch: 7 	 Training Loss: 3.773964
# Epoch: 7 	 Validation precision@k5: 0.5753, accuracy@k5: 0.3100
# Epoch: 7 	 Validation precision@k10: 0.5849, accuracy@k10: 0.5044
# Epoch: 7 	 Validation precision@k15: 0.6325, accuracy@k15: 0.6157
# Epoch: 7 	 Validation precision@k20: 0.7006, accuracy@k20: 0.6990
# Epoch: 7 	 Validation precision@k25: 0.7606, accuracy@k25: 0.7605
# Epoch: 7 	 Validation precision@k30: 0.8096, accuracy@k30: 0.8096
# CPU: 16.33
# RAM %: 61.9
# Epoch: 8 	 Training Loss: 3.728783
# Epoch: 8 	 Validation precision@k5: 0.6417, accuracy@k5: 0.3420
# Epoch: 8 	 Validation precision@k10: 0.5946, accuracy@k10: 0.5133
# Epoch: 8 	 Validation precision@k15: 0.6370, accuracy@k15: 0.6198
# Epoch: 8 	 Validation precision@k20: 0.7004, accuracy@k20: 0.6987
# Epoch: 8 	 Validation precision@k25: 0.7592, accuracy@k25: 0.7591
# Epoch: 8 	 Validation precision@k30: 0.8099, accuracy@k30: 0.8099
# CPU: 16.53
# RAM %: 61.9
# Epoch: 9 	 Training Loss: 3.716052
# Epoch: 9 	 Validation precision@k5: 0.6225, accuracy@k5: 0.3359
# Epoch: 9 	 Validation precision@k10: 0.5721, accuracy@k10: 0.4947
# Epoch: 9 	 Validation precision@k15: 0.6207, accuracy@k15: 0.6046
# Epoch: 9 	 Validation precision@k20: 0.6910, accuracy@k20: 0.6893
# Epoch: 9 	 Validation precision@k25: 0.7536, accuracy@k25: 0.7535
# Epoch: 9 	 Validation precision@k30: 0.8044, accuracy@k30: 0.8044
# CPU: 16.84
# RAM %: 61.9
# Epoch: 10 	 Training Loss: 3.671092
# Epoch: 10 	 Validation precision@k5: 0.6132, accuracy@k5: 0.3300
# Epoch: 10 	 Validation precision@k10: 0.5983, accuracy@k10: 0.5163
# Epoch: 10 	 Validation precision@k15: 0.6448, accuracy@k15: 0.6278
# Epoch: 10 	 Validation precision@k20: 0.7092, accuracy@k20: 0.7075
# Epoch: 10 	 Validation precision@k25: 0.7676, accuracy@k25: 0.7675
# Epoch: 10 	 Validation precision@k30: 0.8151, accuracy@k30: 0.8151
# CPU: 17.02
# RAM %: 61.9
# Epoch: 11 	 Training Loss: 3.671490
# Epoch: 11 	 Validation precision@k5: 0.5695, accuracy@k5: 0.3089
# Epoch: 11 	 Validation precision@k10: 0.5619, accuracy@k10: 0.4864
# Epoch: 11 	 Validation precision@k15: 0.6276, accuracy@k15: 0.6111
# Epoch: 11 	 Validation precision@k20: 0.6980, accuracy@k20: 0.6964
# Epoch: 11 	 Validation precision@k25: 0.7527, accuracy@k25: 0.7526
# Epoch: 11 	 Validation precision@k30: 0.8031, accuracy@k30: 0.8031
# CPU: 17.24
# RAM %: 61.9
# Epoch: 12 	 Training Loss: 3.646777
# Epoch: 12 	 Validation precision@k5: 0.6541, accuracy@k5: 0.3508
# Epoch: 12 	 Validation precision@k10: 0.6133, accuracy@k10: 0.5298
# Epoch: 12 	 Validation precision@k15: 0.6513, accuracy@k15: 0.6338
# Epoch: 12 	 Validation precision@k20: 0.7117, accuracy@k20: 0.7100
# Epoch: 12 	 Validation precision@k25: 0.7699, accuracy@k25: 0.7699
# Epoch: 12 	 Validation precision@k30: 0.8169, accuracy@k30: 0.8169
# CPU: 17.12
# RAM %: 61.9
# Epoch: 13 	 Training Loss: 3.629147
# Epoch: 13 	 Validation precision@k5: 0.6364, accuracy@k5: 0.3437
# Epoch: 13 	 Validation precision@k10: 0.5975, accuracy@k10: 0.5167
# Epoch: 13 	 Validation precision@k15: 0.6286, accuracy@k15: 0.6120
# Epoch: 13 	 Validation precision@k20: 0.6886, accuracy@k20: 0.6870
# Epoch: 13 	 Validation precision@k25: 0.7526, accuracy@k25: 0.7526
# Epoch: 13 	 Validation precision@k30: 0.8058, accuracy@k30: 0.8058
# CPU: 17.12
# RAM %: 61.8
# Epoch: 14 	 Training Loss: 3.609241
# Epoch: 14 	 Validation precision@k5: 0.6324, accuracy@k5: 0.3421
# Epoch: 14 	 Validation precision@k10: 0.5922, accuracy@k10: 0.5123
# Epoch: 14 	 Validation precision@k15: 0.6407, accuracy@k15: 0.6239
# Epoch: 14 	 Validation precision@k20: 0.7197, accuracy@k20: 0.7180
# Epoch: 14 	 Validation precision@k25: 0.7763, accuracy@k25: 0.7762
# Epoch: 14 	 Validation precision@k30: 0.8198, accuracy@k30: 0.8198
# CPU: 17.17
# RAM %: 61.8
# Epoch: 15 	 Training Loss: 3.609652
# Epoch: 15 	 Validation precision@k5: 0.6058, accuracy@k5: 0.3297
# Epoch: 15 	 Validation precision@k10: 0.5952, accuracy@k10: 0.5149
# Epoch: 15 	 Validation precision@k15: 0.6370, accuracy@k15: 0.6202
# Epoch: 15 	 Validation precision@k20: 0.6993, accuracy@k20: 0.6977
# Epoch: 15 	 Validation precision@k25: 0.7605, accuracy@k25: 0.7605
# Epoch: 15 	 Validation precision@k30: 0.8121, accuracy@k30: 0.8121
# CPU: 17.12
# RAM %: 61.8
# Epoch: 16 	 Training Loss: 3.591067
# Epoch: 16 	 Validation precision@k5: 0.6623, accuracy@k5: 0.3579
# Epoch: 16 	 Validation precision@k10: 0.6076, accuracy@k10: 0.5253
# Epoch: 16 	 Validation precision@k15: 0.6446, accuracy@k15: 0.6279
# Epoch: 16 	 Validation precision@k20: 0.7048, accuracy@k20: 0.7032
# Epoch: 16 	 Validation precision@k25: 0.7666, accuracy@k25: 0.7665
# Epoch: 16 	 Validation precision@k30: 0.8203, accuracy@k30: 0.8203
# CPU: 16.95
# RAM %: 61.9
# Epoch: 17 	 Training Loss: 3.577525
# Epoch: 17 	 Validation precision@k5: 0.6613, accuracy@k5: 0.3562
# Epoch: 17 	 Validation precision@k10: 0.6144, accuracy@k10: 0.5314
# Epoch: 17 	 Validation precision@k15: 0.6478, accuracy@k15: 0.6307
# Epoch: 17 	 Validation precision@k20: 0.7097, accuracy@k20: 0.7080
# Epoch: 17 	 Validation precision@k25: 0.7688, accuracy@k25: 0.7687
# Epoch: 17 	 Validation precision@k30: 0.8101, accuracy@k30: 0.8101
# CPU: 16.88
# RAM %: 61.8
# Epoch: 18 	 Training Loss: 3.572515
# Epoch: 18 	 Validation precision@k5: 0.6353, accuracy@k5: 0.3446
# Epoch: 18 	 Validation precision@k10: 0.5975, accuracy@k10: 0.5172
# Epoch: 18 	 Validation precision@k15: 0.6484, accuracy@k15: 0.6313
# Epoch: 18 	 Validation precision@k20: 0.7122, accuracy@k20: 0.7106
# Epoch: 18 	 Validation precision@k25: 0.7693, accuracy@k25: 0.7692
# Epoch: 18 	 Validation precision@k30: 0.8184, accuracy@k30: 0.8184
# CPU: 16.81
# RAM %: 61.8
# Epoch: 19 	 Training Loss: 3.559059
# Epoch: 19 	 Validation precision@k5: 0.6546, accuracy@k5: 0.3539
# Epoch: 19 	 Validation precision@k10: 0.6095, accuracy@k10: 0.5286
# Epoch: 19 	 Validation precision@k15: 0.6518, accuracy@k15: 0.6352
# Epoch: 19 	 Validation precision@k20: 0.7144, accuracy@k20: 0.7128
# Epoch: 19 	 Validation precision@k25: 0.7734, accuracy@k25: 0.7733
# Epoch: 19 	 Validation precision@k30: 0.8183, accuracy@k30: 0.8183
# CPU: 16.74
# RAM %: 61.8
# Epoch: 20 	 Training Loss: 3.552010
# Epoch: 20 	 Validation precision@k5: 0.6297, accuracy@k5: 0.3427
# Epoch: 20 	 Validation precision@k10: 0.5813, accuracy@k10: 0.5049
# Epoch: 20 	 Validation precision@k15: 0.6372, accuracy@k15: 0.6208
# Epoch: 20 	 Validation precision@k20: 0.7081, accuracy@k20: 0.7065
# Epoch: 20 	 Validation precision@k25: 0.7743, accuracy@k25: 0.7742
# Epoch: 20 	 Validation precision@k30: 0.8226, accuracy@k30: 0.8226
# CPU: 16.89
# RAM %: 61.8
# Epoch: 21 	 Training Loss: 3.535679
# Epoch: 21 	 Validation precision@k5: 0.6336, accuracy@k5: 0.3454
# Epoch: 21 	 Validation precision@k10: 0.6044, accuracy@k10: 0.5226
# Epoch: 21 	 Validation precision@k15: 0.6541, accuracy@k15: 0.6369
# Epoch: 21 	 Validation precision@k20: 0.7190, accuracy@k20: 0.7173
# Epoch: 21 	 Validation precision@k25: 0.7767, accuracy@k25: 0.7766
# Epoch: 21 	 Validation precision@k30: 0.8216, accuracy@k30: 0.8216
# CPU: 17.00
# RAM %: 61.9
# Epoch: 22 	 Training Loss: 3.531054
# Epoch: 22 	 Validation precision@k5: 0.6302, accuracy@k5: 0.3430
# Epoch: 22 	 Validation precision@k10: 0.5986, accuracy@k10: 0.5193
# Epoch: 22 	 Validation precision@k15: 0.6492, accuracy@k15: 0.6324
# Epoch: 22 	 Validation precision@k20: 0.7125, accuracy@k20: 0.7109
# Epoch: 22 	 Validation precision@k25: 0.7735, accuracy@k25: 0.7734
# Epoch: 22 	 Validation precision@k30: 0.8184, accuracy@k30: 0.8184
# CPU: 17.49
# RAM %: 61.8
# Epoch: 23 	 Training Loss: 3.530746
# Epoch: 23 	 Validation precision@k5: 0.6483, accuracy@k5: 0.3496
# Epoch: 23 	 Validation precision@k10: 0.6215, accuracy@k10: 0.5370
# Epoch: 23 	 Validation precision@k15: 0.6599, accuracy@k15: 0.6423
# Epoch: 23 	 Validation precision@k20: 0.7239, accuracy@k20: 0.7222
# Epoch: 23 	 Validation precision@k25: 0.7780, accuracy@k25: 0.7779
# Epoch: 23 	 Validation precision@k30: 0.8232, accuracy@k30: 0.8232
# CPU: 17.69
# RAM %: 61.9
# Epoch: 24 	 Training Loss: 3.518619
# Epoch: 24 	 Validation precision@k5: 0.6389, accuracy@k5: 0.3485
# Epoch: 24 	 Validation precision@k10: 0.6101, accuracy@k10: 0.5281
# Epoch: 24 	 Validation precision@k15: 0.6530, accuracy@k15: 0.6359
# Epoch: 24 	 Validation precision@k20: 0.7235, accuracy@k20: 0.7218
# Epoch: 24 	 Validation precision@k25: 0.7844, accuracy@k25: 0.7843
# Epoch: 24 	 Validation precision@k30: 0.8297, accuracy@k30: 0.8297
# CPU: 17.69
# RAM %: 61.8
# Epoch: 25 	 Training Loss: 3.512872
# Epoch: 25 	 Validation precision@k5: 0.6684, accuracy@k5: 0.3629
# Epoch: 25 	 Validation precision@k10: 0.6076, accuracy@k10: 0.5269
# Epoch: 25 	 Validation precision@k15: 0.6564, accuracy@k15: 0.6394
# Epoch: 25 	 Validation precision@k20: 0.7249, accuracy@k20: 0.7233
# Epoch: 25 	 Validation precision@k25: 0.7824, accuracy@k25: 0.7823
# Epoch: 25 	 Validation precision@k30: 0.8270, accuracy@k30: 0.8270
# CPU: 18.03
# RAM %: 61.8
# Epoch: 26 	 Training Loss: 3.503156
# Epoch: 26 	 Validation precision@k5: 0.6792, accuracy@k5: 0.3703
# Epoch: 26 	 Validation precision@k10: 0.6297, accuracy@k10: 0.5453
# Epoch: 26 	 Validation precision@k15: 0.6683, accuracy@k15: 0.6508
# Epoch: 26 	 Validation precision@k20: 0.7258, accuracy@k20: 0.7242
# Epoch: 26 	 Validation precision@k25: 0.7776, accuracy@k25: 0.7776
# Epoch: 26 	 Validation precision@k30: 0.8245, accuracy@k30: 0.8245
# CPU: 18.01
# RAM %: 61.8
# Epoch: 27 	 Training Loss: 3.493230
# Epoch: 27 	 Validation precision@k5: 0.6251, accuracy@k5: 0.3399
# Epoch: 27 	 Validation precision@k10: 0.5927, accuracy@k10: 0.5142
# Epoch: 27 	 Validation precision@k15: 0.6472, accuracy@k15: 0.6305
# Epoch: 27 	 Validation precision@k20: 0.7199, accuracy@k20: 0.7183
# Epoch: 27 	 Validation precision@k25: 0.7805, accuracy@k25: 0.7804
# Epoch: 27 	 Validation precision@k30: 0.8233, accuracy@k30: 0.8233
# CPU: 17.99
# RAM %: 61.8
# Epoch: 28 	 Training Loss: 3.493271
# Epoch: 28 	 Validation precision@k5: 0.6375, accuracy@k5: 0.3463
# Epoch: 28 	 Validation precision@k10: 0.6086, accuracy@k10: 0.5265
# Epoch: 28 	 Validation precision@k15: 0.6608, accuracy@k15: 0.6434
# Epoch: 28 	 Validation precision@k20: 0.7286, accuracy@k20: 0.7269
# Epoch: 28 	 Validation precision@k25: 0.7859, accuracy@k25: 0.7858
# Epoch: 28 	 Validation precision@k30: 0.8308, accuracy@k30: 0.8308
# CPU: 18.08
# RAM %: 61.8
# Epoch: 29 	 Training Loss: 3.481494
# Epoch: 29 	 Validation precision@k5: 0.6809, accuracy@k5: 0.3693
# Epoch: 29 	 Validation precision@k10: 0.6314, accuracy@k10: 0.5458
# Epoch: 29 	 Validation precision@k15: 0.6663, accuracy@k15: 0.6491
# Epoch: 29 	 Validation precision@k20: 0.7240, accuracy@k20: 0.7223
# Epoch: 29 	 Validation precision@k25: 0.7825, accuracy@k25: 0.7824
# Epoch: 29 	 Validation precision@k30: 0.8253, accuracy@k30: 0.8253
# CPU: 17.98
# RAM %: 61.9
# Epoch: 30 	 Training Loss: 3.481126
# Epoch: 30 	 Validation precision@k5: 0.6730, accuracy@k5: 0.3680
# Epoch: 30 	 Validation precision@k10: 0.6284, accuracy@k10: 0.5437
# Epoch: 30 	 Validation precision@k15: 0.6623, accuracy@k15: 0.6450
# Epoch: 30 	 Validation precision@k20: 0.7249, accuracy@k20: 0.7232
# Epoch: 30 	 Validation precision@k25: 0.7844, accuracy@k25: 0.7843
# Epoch: 30 	 Validation precision@k30: 0.8297, accuracy@k30: 0.8297
# CPU: 17.88
# RAM %: 61.8
# Epoch: 31 	 Training Loss: 3.470470
# Epoch: 31 	 Validation precision@k5: 0.6578, accuracy@k5: 0.3582
# Epoch: 31 	 Validation precision@k10: 0.6214, accuracy@k10: 0.5388
# Epoch: 31 	 Validation precision@k15: 0.6700, accuracy@k15: 0.6527
# Epoch: 31 	 Validation precision@k20: 0.7278, accuracy@k20: 0.7262
# Epoch: 31 	 Validation precision@k25: 0.7834, accuracy@k25: 0.7833
# Epoch: 31 	 Validation precision@k30: 0.8315, accuracy@k30: 0.8315
# CPU: 17.86
# RAM %: 61.8
# Epoch: 32 	 Training Loss: 3.466856
# Epoch: 32 	 Validation precision@k5: 0.6695, accuracy@k5: 0.3630
# Epoch: 32 	 Validation precision@k10: 0.6267, accuracy@k10: 0.5427
# Epoch: 32 	 Validation precision@k15: 0.6727, accuracy@k15: 0.6550
# Epoch: 32 	 Validation precision@k20: 0.7366, accuracy@k20: 0.7349
# Epoch: 32 	 Validation precision@k25: 0.7906, accuracy@k25: 0.7905
# Epoch: 32 	 Validation precision@k30: 0.8323, accuracy@k30: 0.8323
# CPU: 17.87
# RAM %: 61.8
# Epoch: 33 	 Training Loss: 3.459626
# Epoch: 33 	 Validation precision@k5: 0.6806, accuracy@k5: 0.3708
# Epoch: 33 	 Validation precision@k10: 0.6261, accuracy@k10: 0.5421
# Epoch: 33 	 Validation precision@k15: 0.6721, accuracy@k15: 0.6547
# Epoch: 33 	 Validation precision@k20: 0.7343, accuracy@k20: 0.7327
# Epoch: 33 	 Validation precision@k25: 0.7827, accuracy@k25: 0.7826
# Epoch: 33 	 Validation precision@k30: 0.8270, accuracy@k30: 0.8270
# CPU: 17.89
# RAM %: 61.8
# Epoch: 34 	 Training Loss: 3.455314
# Epoch: 34 	 Validation precision@k5: 0.6792, accuracy@k5: 0.3696
# Epoch: 34 	 Validation precision@k10: 0.6382, accuracy@k10: 0.5524
# Epoch: 34 	 Validation precision@k15: 0.6717, accuracy@k15: 0.6542
# Epoch: 34 	 Validation precision@k20: 0.7293, accuracy@k20: 0.7276
# Epoch: 34 	 Validation precision@k25: 0.7870, accuracy@k25: 0.7869
# Epoch: 34 	 Validation precision@k30: 0.8318, accuracy@k30: 0.8318
# CPU: 18.01
# RAM %: 61.9
# Epoch: 35 	 Training Loss: 3.449673
# Epoch: 35 	 Validation precision@k5: 0.6810, accuracy@k5: 0.3674
# Epoch: 35 	 Validation precision@k10: 0.6431, accuracy@k10: 0.5559
# Epoch: 35 	 Validation precision@k15: 0.6775, accuracy@k15: 0.6595
# Epoch: 35 	 Validation precision@k20: 0.7325, accuracy@k20: 0.7308
# Epoch: 35 	 Validation precision@k25: 0.7893, accuracy@k25: 0.7892
# Epoch: 35 	 Validation precision@k30: 0.8335, accuracy@k30: 0.8335
# CPU: 17.99
# RAM %: 61.9
# Epoch: 36 	 Training Loss: 3.443774
# Epoch: 36 	 Validation precision@k5: 0.6760, accuracy@k5: 0.3665
# Epoch: 36 	 Validation precision@k10: 0.6394, accuracy@k10: 0.5530
# Epoch: 36 	 Validation precision@k15: 0.6817, accuracy@k15: 0.6638
# Epoch: 36 	 Validation precision@k20: 0.7390, accuracy@k20: 0.7373
# Epoch: 36 	 Validation precision@k25: 0.7945, accuracy@k25: 0.7944
# Epoch: 36 	 Validation precision@k30: 0.8364, accuracy@k30: 0.8364
# CPU: 18.19
# RAM %: 61.8
# Epoch: 37 	 Training Loss: 3.437498
# Epoch: 37 	 Validation precision@k5: 0.6911, accuracy@k5: 0.3730
# Epoch: 37 	 Validation precision@k10: 0.6447, accuracy@k10: 0.5575
# Epoch: 37 	 Validation precision@k15: 0.6822, accuracy@k15: 0.6642
# Epoch: 37 	 Validation precision@k20: 0.7340, accuracy@k20: 0.7323
# Epoch: 37 	 Validation precision@k25: 0.7886, accuracy@k25: 0.7885
# Epoch: 37 	 Validation precision@k30: 0.8363, accuracy@k30: 0.8363
# CPU: 18.09
# RAM %: 61.8
# Epoch: 38 	 Training Loss: 3.432912
# Epoch: 38 	 Validation precision@k5: 0.6923, accuracy@k5: 0.3767
# Epoch: 38 	 Validation precision@k10: 0.6351, accuracy@k10: 0.5491
# Epoch: 38 	 Validation precision@k15: 0.6758, accuracy@k15: 0.6579
# Epoch: 38 	 Validation precision@k20: 0.7365, accuracy@k20: 0.7347
# Epoch: 38 	 Validation precision@k25: 0.7901, accuracy@k25: 0.7900
# Epoch: 38 	 Validation precision@k30: 0.8340, accuracy@k30: 0.8340
# CPU: 18.32
# RAM %: 61.8
# Epoch: 39 	 Training Loss: 3.429636
# Epoch: 39 	 Validation precision@k5: 0.6830, accuracy@k5: 0.3682
# Epoch: 39 	 Validation precision@k10: 0.6457, accuracy@k10: 0.5577
# Epoch: 39 	 Validation precision@k15: 0.6800, accuracy@k15: 0.6621
# Epoch: 39 	 Validation precision@k20: 0.7380, accuracy@k20: 0.7363
# Epoch: 39 	 Validation precision@k25: 0.7939, accuracy@k25: 0.7938
# Epoch: 39 	 Validation precision@k30: 0.8351, accuracy@k30: 0.8351
# CPU: 18.80
# RAM %: 61.9
# Epoch: 40 	 Training Loss: 3.424982
# Epoch: 40 	 Validation precision@k5: 0.6966, accuracy@k5: 0.3784
# Epoch: 40 	 Validation precision@k10: 0.6487, accuracy@k10: 0.5600
# Epoch: 40 	 Validation precision@k15: 0.6841, accuracy@k15: 0.6658
# Epoch: 40 	 Validation precision@k20: 0.7407, accuracy@k20: 0.7390
# Epoch: 40 	 Validation precision@k25: 0.7950, accuracy@k25: 0.7949
# Epoch: 40 	 Validation precision@k30: 0.8394, accuracy@k30: 0.8394
# CPU: 19.18
# RAM %: 61.9
# Epoch: 41 	 Training Loss: 3.420572
# Epoch: 41 	 Validation precision@k5: 0.6807, accuracy@k5: 0.3680
# Epoch: 41 	 Validation precision@k10: 0.6456, accuracy@k10: 0.5571
# Epoch: 41 	 Validation precision@k15: 0.6858, accuracy@k15: 0.6672
# Epoch: 41 	 Validation precision@k20: 0.7432, accuracy@k20: 0.7415
# Epoch: 41 	 Validation precision@k25: 0.7971, accuracy@k25: 0.7970
# Epoch: 41 	 Validation precision@k30: 0.8391, accuracy@k30: 0.8391
# CPU: 19.27
# RAM %: 61.9
# Epoch: 42 	 Training Loss: 3.419021
# Epoch: 42 	 Validation precision@k5: 0.6912, accuracy@k5: 0.3742
# Epoch: 42 	 Validation precision@k10: 0.6500, accuracy@k10: 0.5616
# Epoch: 42 	 Validation precision@k15: 0.6832, accuracy@k15: 0.6648
# Epoch: 42 	 Validation precision@k20: 0.7439, accuracy@k20: 0.7422
# Epoch: 42 	 Validation precision@k25: 0.7995, accuracy@k25: 0.7994
# Epoch: 42 	 Validation precision@k30: 0.8376, accuracy@k30: 0.8376
# CPU: 19.50
# RAM %: 61.9
# Epoch: 43 	 Training Loss: 3.415067
# Epoch: 43 	 Validation precision@k5: 0.6750, accuracy@k5: 0.3625
# Epoch: 43 	 Validation precision@k10: 0.6496, accuracy@k10: 0.5606
# Epoch: 43 	 Validation precision@k15: 0.6826, accuracy@k15: 0.6644
# Epoch: 43 	 Validation precision@k20: 0.7405, accuracy@k20: 0.7388
# Epoch: 43 	 Validation precision@k25: 0.8014, accuracy@k25: 0.8013
# Epoch: 43 	 Validation precision@k30: 0.8402, accuracy@k30: 0.8402
# CPU: 19.40
# RAM %: 61.8
# Epoch: 44 	 Training Loss: 3.411563
# Epoch: 44 	 Validation precision@k5: 0.6961, accuracy@k5: 0.3762
# Epoch: 44 	 Validation precision@k10: 0.6526, accuracy@k10: 0.5626
# Epoch: 44 	 Validation precision@k15: 0.6863, accuracy@k15: 0.6678
# Epoch: 44 	 Validation precision@k20: 0.7454, accuracy@k20: 0.7436
# Epoch: 44 	 Validation precision@k25: 0.7954, accuracy@k25: 0.7954
# Epoch: 44 	 Validation precision@k30: 0.8387, accuracy@k30: 0.8387
# CPU: 19.34
# RAM %: 61.8
# Epoch: 45 	 Training Loss: 3.411551
# Epoch: 45 	 Validation precision@k5: 0.7054, accuracy@k5: 0.3813
# Epoch: 45 	 Validation precision@k10: 0.6518, accuracy@k10: 0.5621
# Epoch: 45 	 Validation precision@k15: 0.6870, accuracy@k15: 0.6685
# Epoch: 45 	 Validation precision@k20: 0.7432, accuracy@k20: 0.7415
# Epoch: 45 	 Validation precision@k25: 0.7975, accuracy@k25: 0.7974
# Epoch: 45 	 Validation precision@k30: 0.8384, accuracy@k30: 0.8384
# CPU: 18.99
# RAM %: 61.8
# Epoch: 46 	 Training Loss: 3.407556
# Epoch: 46 	 Validation precision@k5: 0.6769, accuracy@k5: 0.3659
# Epoch: 46 	 Validation precision@k10: 0.6501, accuracy@k10: 0.5607
# Epoch: 46 	 Validation precision@k15: 0.6846, accuracy@k15: 0.6659
# Epoch: 46 	 Validation precision@k20: 0.7422, accuracy@k20: 0.7404
# Epoch: 46 	 Validation precision@k25: 0.7977, accuracy@k25: 0.7976
# Epoch: 46 	 Validation precision@k30: 0.8391, accuracy@k30: 0.8391
# CPU: 18.83
# RAM %: 61.9
# Epoch: 47 	 Training Loss: 3.406333
# Epoch: 47 	 Validation precision@k5: 0.6922, accuracy@k5: 0.3715
# Epoch: 47 	 Validation precision@k10: 0.6593, accuracy@k10: 0.5681
# Epoch: 47 	 Validation precision@k15: 0.6920, accuracy@k15: 0.6732
# Epoch: 47 	 Validation precision@k20: 0.7412, accuracy@k20: 0.7394
# Epoch: 47 	 Validation precision@k25: 0.7974, accuracy@k25: 0.7973
# Epoch: 47 	 Validation precision@k30: 0.8426, accuracy@k30: 0.8426
# CPU: 18.85
# RAM %: 61.9
# Epoch: 48 	 Training Loss: 3.403323
# Epoch: 48 	 Validation precision@k5: 0.6904, accuracy@k5: 0.3730
# Epoch: 48 	 Validation precision@k10: 0.6573, accuracy@k10: 0.5664
# Epoch: 48 	 Validation precision@k15: 0.6898, accuracy@k15: 0.6710
# Epoch: 48 	 Validation precision@k20: 0.7414, accuracy@k20: 0.7397
# Epoch: 48 	 Validation precision@k25: 0.7993, accuracy@k25: 0.7992
# Epoch: 48 	 Validation precision@k30: 0.8422, accuracy@k30: 0.8422
# CPU: 19.38
# RAM %: 61.9
# Epoch: 49 	 Training Loss: 3.401559
# Epoch: 49 	 Validation precision@k5: 0.6856, accuracy@k5: 0.3708
# Epoch: 49 	 Validation precision@k10: 0.6493, accuracy@k10: 0.5596
# Epoch: 49 	 Validation precision@k15: 0.6860, accuracy@k15: 0.6672
# Epoch: 49 	 Validation precision@k20: 0.7449, accuracy@k20: 0.7431
# Epoch: 49 	 Validation precision@k25: 0.8013, accuracy@k25: 0.8012
# Epoch: 49 	 Validation precision@k30: 0.8416, accuracy@k30: 0.8416
# CPU: 19.35
# RAM %: 61.9
# Epoch: 50 	 Training Loss: 3.399208
# Epoch: 50 	 Validation precision@k5: 0.6881, accuracy@k5: 0.3703
# Epoch: 50 	 Validation precision@k10: 0.6511, accuracy@k10: 0.5605
# Epoch: 50 	 Validation precision@k15: 0.6850, accuracy@k15: 0.6662
# Epoch: 50 	 Validation precision@k20: 0.7431, accuracy@k20: 0.7412
# Epoch: 50 	 Validation precision@k25: 0.7999, accuracy@k25: 0.7998
# Epoch: 50 	 Validation precision@k30: 0.8416, accuracy@k30: 0.8416
# CPU: 19.34
# RAM %: 62.0
# Epoch: 51 	 Training Loss: 3.399660
# Epoch: 51 	 Validation precision@k5: 0.6945, accuracy@k5: 0.3749
# Epoch: 51 	 Validation precision@k10: 0.6551, accuracy@k10: 0.5646
# Epoch: 51 	 Validation precision@k15: 0.6865, accuracy@k15: 0.6676
# Epoch: 51 	 Validation precision@k20: 0.7441, accuracy@k20: 0.7423
# Epoch: 51 	 Validation precision@k25: 0.8015, accuracy@k25: 0.8014
# Epoch: 51 	 Validation precision@k30: 0.8434, accuracy@k30: 0.8434
# CPU: 19.42
# RAM %: 62.0
# Epoch: 52 	 Training Loss: 3.396973
# Epoch: 52 	 Validation precision@k5: 0.6854, accuracy@k5: 0.3697
# Epoch: 52 	 Validation precision@k10: 0.6580, accuracy@k10: 0.5665
# Epoch: 52 	 Validation precision@k15: 0.6894, accuracy@k15: 0.6702
# Epoch: 52 	 Validation precision@k20: 0.7455, accuracy@k20: 0.7437
# Epoch: 52 	 Validation precision@k25: 0.8020, accuracy@k25: 0.8019
# Epoch: 52 	 Validation precision@k30: 0.8404, accuracy@k30: 0.8404
# CPU: 19.38
# RAM %: 62.0
# Epoch: 53 	 Training Loss: 3.395535
# Epoch: 53 	 Validation precision@k5: 0.7000, accuracy@k5: 0.3780
# Epoch: 53 	 Validation precision@k10: 0.6547, accuracy@k10: 0.5636
# Epoch: 53 	 Validation precision@k15: 0.6869, accuracy@k15: 0.6680
# Epoch: 53 	 Validation precision@k20: 0.7409, accuracy@k20: 0.7391
# Epoch: 53 	 Validation precision@k25: 0.7983, accuracy@k25: 0.7982
# Epoch: 53 	 Validation precision@k30: 0.8422, accuracy@k30: 0.8422
# CPU: 19.36
# RAM %: 62.0
# Epoch: 54 	 Training Loss: 3.394619
# Epoch: 54 	 Validation precision@k5: 0.6910, accuracy@k5: 0.3716
# Epoch: 54 	 Validation precision@k10: 0.6552, accuracy@k10: 0.5641
# Epoch: 54 	 Validation precision@k15: 0.6867, accuracy@k15: 0.6676
# Epoch: 54 	 Validation precision@k20: 0.7414, accuracy@k20: 0.7396
# Epoch: 54 	 Validation precision@k25: 0.7980, accuracy@k25: 0.7979
# Epoch: 54 	 Validation precision@k30: 0.8415, accuracy@k30: 0.8415
# CPU: 19.33
# RAM %: 61.9
# Epoch: 55 	 Training Loss: 3.394301
# Epoch: 55 	 Validation precision@k5: 0.6971, accuracy@k5: 0.3749
# Epoch: 55 	 Validation precision@k10: 0.6556, accuracy@k10: 0.5646
# Epoch: 55 	 Validation precision@k15: 0.6843, accuracy@k15: 0.6653
# Epoch: 55 	 Validation precision@k20: 0.7416, accuracy@k20: 0.7398
# Epoch: 55 	 Validation precision@k25: 0.7987, accuracy@k25: 0.7986
# Epoch: 55 	 Validation precision@k30: 0.8405, accuracy@k30: 0.8405
# CPU: 19.27
# RAM %: 62.0
# Epoch: 56 	 Training Loss: 3.393245
# Epoch: 56 	 Validation precision@k5: 0.6903, accuracy@k5: 0.3713
# Epoch: 56 	 Validation precision@k10: 0.6547, accuracy@k10: 0.5633
# Epoch: 56 	 Validation precision@k15: 0.6890, accuracy@k15: 0.6698
# Epoch: 56 	 Validation precision@k20: 0.7459, accuracy@k20: 0.7441
# Epoch: 56 	 Validation precision@k25: 0.7992, accuracy@k25: 0.7991
# Epoch: 56 	 Validation precision@k30: 0.8393, accuracy@k30: 0.8393
# CPU: 19.28
# RAM %: 62.0
# Epoch: 57 	 Training Loss: 3.393621
# Epoch: 57 	 Validation precision@k5: 0.7002, accuracy@k5: 0.3767
# Epoch: 57 	 Validation precision@k10: 0.6631, accuracy@k10: 0.5709
# Epoch: 57 	 Validation precision@k15: 0.6896, accuracy@k15: 0.6705
# Epoch: 57 	 Validation precision@k20: 0.7437, accuracy@k20: 0.7419
# Epoch: 57 	 Validation precision@k25: 0.7972, accuracy@k25: 0.7971
# Epoch: 57 	 Validation precision@k30: 0.8402, accuracy@k30: 0.8402
# CPU: 19.59
# RAM %: 62.0
# Epoch: 58 	 Training Loss: 3.392533
# Epoch: 58 	 Validation precision@k5: 0.7031, accuracy@k5: 0.3793
# Epoch: 58 	 Validation precision@k10: 0.6584, accuracy@k10: 0.5666
# Epoch: 58 	 Validation precision@k15: 0.6872, accuracy@k15: 0.6681
# Epoch: 58 	 Validation precision@k20: 0.7420, accuracy@k20: 0.7401
# Epoch: 58 	 Validation precision@k25: 0.8000, accuracy@k25: 0.7999
# Epoch: 58 	 Validation precision@k30: 0.8400, accuracy@k30: 0.8400
# CPU: 19.78
# RAM %: 62.0
# Epoch: 59 	 Training Loss: 3.392247
# Epoch: 59 	 Validation precision@k5: 0.6944, accuracy@k5: 0.3725
# Epoch: 59 	 Validation precision@k10: 0.6574, accuracy@k10: 0.5657
# Epoch: 59 	 Validation precision@k15: 0.6894, accuracy@k15: 0.6701
# Epoch: 59 	 Validation precision@k20: 0.7439, accuracy@k20: 0.7420
# Epoch: 59 	 Validation precision@k25: 0.7975, accuracy@k25: 0.7974
# Epoch: 59 	 Validation precision@k30: 0.8415, accuracy@k30: 0.8415
# CPU: 19.81
# RAM %: 62.0
# Epoch: 60 	 Training Loss: 3.391110
# Epoch: 60 	 Validation precision@k5: 0.7017, accuracy@k5: 0.3788
# Epoch: 60 	 Validation precision@k10: 0.6600, accuracy@k10: 0.5683
# Epoch: 60 	 Validation precision@k15: 0.6868, accuracy@k15: 0.6676
# Epoch: 60 	 Validation precision@k20: 0.7433, accuracy@k20: 0.7415
# Epoch: 60 	 Validation precision@k25: 0.7999, accuracy@k25: 0.7998
# Epoch: 60 	 Validation precision@k30: 0.8387, accuracy@k30: 0.8387
# CPU: 19.74
# RAM %: 62.0
# Epoch: 61 	 Training Loss: 3.391443
# Epoch: 61 	 Validation precision@k5: 0.6922, accuracy@k5: 0.3725
# Epoch: 61 	 Validation precision@k10: 0.6597, accuracy@k10: 0.5680
# Epoch: 61 	 Validation precision@k15: 0.6895, accuracy@k15: 0.6703
# Epoch: 61 	 Validation precision@k20: 0.7438, accuracy@k20: 0.7419
# Epoch: 61 	 Validation precision@k25: 0.8001, accuracy@k25: 0.8000
# Epoch: 61 	 Validation precision@k30: 0.8395, accuracy@k30: 0.8395
# CPU: 20.17
# RAM %: 62.0
# Epoch: 62 	 Training Loss: 3.390612
# Epoch: 62 	 Validation precision@k5: 0.6875, accuracy@k5: 0.3709
# Epoch: 62 	 Validation precision@k10: 0.6568, accuracy@k10: 0.5653
# Epoch: 62 	 Validation precision@k15: 0.6857, accuracy@k15: 0.6668
# Epoch: 62 	 Validation precision@k20: 0.7401, accuracy@k20: 0.7383
# Epoch: 62 	 Validation precision@k25: 0.7958, accuracy@k25: 0.7957
# Epoch: 62 	 Validation precision@k30: 0.8419, accuracy@k30: 0.8419
# CPU: 20.14
# RAM %: 62.0
# Epoch: 63 	 Training Loss: 3.390591
# Epoch: 63 	 Validation precision@k5: 0.6852, accuracy@k5: 0.3692
# Epoch: 63 	 Validation precision@k10: 0.6564, accuracy@k10: 0.5646
# Epoch: 63 	 Validation precision@k15: 0.6877, accuracy@k15: 0.6685
# Epoch: 63 	 Validation precision@k20: 0.7426, accuracy@k20: 0.7408
# Epoch: 63 	 Validation precision@k25: 0.7987, accuracy@k25: 0.7986
# Epoch: 63 	 Validation precision@k30: 0.8388, accuracy@k30: 0.8388
# CPU: 20.56
# RAM %: 62.0
# Epoch: 64 	 Training Loss: 3.389275
# Epoch: 64 	 Validation precision@k5: 0.7018, accuracy@k5: 0.3771
# Epoch: 64 	 Validation precision@k10: 0.6604, accuracy@k10: 0.5685
# Epoch: 64 	 Validation precision@k15: 0.6886, accuracy@k15: 0.6695
# Epoch: 64 	 Validation precision@k20: 0.7425, accuracy@k20: 0.7406
# Epoch: 64 	 Validation precision@k25: 0.7979, accuracy@k25: 0.7978
# Epoch: 64 	 Validation precision@k30: 0.8404, accuracy@k30: 0.8404
# CPU: 20.54
# RAM %: 62.0
# Epoch: 65 	 Training Loss: 3.389587
# Epoch: 65 	 Validation precision@k5: 0.6891, accuracy@k5: 0.3704
# Epoch: 65 	 Validation precision@k10: 0.6526, accuracy@k10: 0.5617
# Epoch: 65 	 Validation precision@k15: 0.6832, accuracy@k15: 0.6642
# Epoch: 65 	 Validation precision@k20: 0.7434, accuracy@k20: 0.7416
# Epoch: 65 	 Validation precision@k25: 0.7992, accuracy@k25: 0.7991
# Epoch: 65 	 Validation precision@k30: 0.8385, accuracy@k30: 0.8385
# CPU: 21.00
# RAM %: 62.0
# Epoch: 66 	 Training Loss: 3.388435
# Epoch: 66 	 Validation precision@k5: 0.6995, accuracy@k5: 0.3749
# Epoch: 66 	 Validation precision@k10: 0.6534, accuracy@k10: 0.5622
# Epoch: 66 	 Validation precision@k15: 0.6819, accuracy@k15: 0.6631
# Epoch: 66 	 Validation precision@k20: 0.7429, accuracy@k20: 0.7411
# Epoch: 66 	 Validation precision@k25: 0.7939, accuracy@k25: 0.7938
# Epoch: 66 	 Validation precision@k30: 0.8374, accuracy@k30: 0.8374
# CPU: 21.39
# RAM %: 62.0
# Epoch: 67 	 Training Loss: 3.389353
# Epoch: 67 	 Validation precision@k5: 0.6920, accuracy@k5: 0.3717
# Epoch: 67 	 Validation precision@k10: 0.6600, accuracy@k10: 0.5683
# Epoch: 67 	 Validation precision@k15: 0.6860, accuracy@k15: 0.6668
# Epoch: 67 	 Validation precision@k20: 0.7462, accuracy@k20: 0.7444
# Epoch: 67 	 Validation precision@k25: 0.7997, accuracy@k25: 0.7996
# Epoch: 67 	 Validation precision@k30: 0.8407, accuracy@k30: 0.8407
# CPU: 21.18
# RAM %: 62.0
# Epoch: 68 	 Training Loss: 3.389352
# Epoch: 68 	 Validation precision@k5: 0.6937, accuracy@k5: 0.3728
# Epoch: 68 	 Validation precision@k10: 0.6593, accuracy@k10: 0.5671
# Epoch: 68 	 Validation precision@k15: 0.6894, accuracy@k15: 0.6702
# Epoch: 68 	 Validation precision@k20: 0.7449, accuracy@k20: 0.7430
# Epoch: 68 	 Validation precision@k25: 0.7982, accuracy@k25: 0.7981
# Epoch: 68 	 Validation precision@k30: 0.8388, accuracy@k30: 0.8388
# CPU: 21.28
# RAM %: 62.0
# Epoch: 69 	 Training Loss: 3.389363
# Epoch: 69 	 Validation precision@k5: 0.6970, accuracy@k5: 0.3757
# Epoch: 69 	 Validation precision@k10: 0.6570, accuracy@k10: 0.5653
# Epoch: 69 	 Validation precision@k15: 0.6843, accuracy@k15: 0.6652
# Epoch: 69 	 Validation precision@k20: 0.7418, accuracy@k20: 0.7399
# Epoch: 69 	 Validation precision@k25: 0.7987, accuracy@k25: 0.7986
# Epoch: 69 	 Validation precision@k30: 0.8402, accuracy@k30: 0.8402
# CPU: 21.22
# RAM %: 62.0
# Epoch: 70 	 Training Loss: 3.388255
# Epoch: 70 	 Validation precision@k5: 0.6950, accuracy@k5: 0.3739
# Epoch: 70 	 Validation precision@k10: 0.6525, accuracy@k10: 0.5616
# Epoch: 70 	 Validation precision@k15: 0.6861, accuracy@k15: 0.6669
# Epoch: 70 	 Validation precision@k20: 0.7444, accuracy@k20: 0.7426
# Epoch: 70 	 Validation precision@k25: 0.7993, accuracy@k25: 0.7992
# Epoch: 70 	 Validation precision@k30: 0.8401, accuracy@k30: 0.8401
# CPU: 21.35
# RAM %: 62.0
# Epoch: 71 	 Training Loss: 3.389044
# Epoch: 71 	 Validation precision@k5: 0.6983, accuracy@k5: 0.3762
# Epoch: 71 	 Validation precision@k10: 0.6519, accuracy@k10: 0.5609
# Epoch: 71 	 Validation precision@k15: 0.6857, accuracy@k15: 0.6664
# Epoch: 71 	 Validation precision@k20: 0.7423, accuracy@k20: 0.7405
# Epoch: 71 	 Validation precision@k25: 0.7990, accuracy@k25: 0.7989
# Epoch: 71 	 Validation precision@k30: 0.8406, accuracy@k30: 0.8406
# CPU: 21.31
# RAM %: 62.0
# Epoch: 72 	 Training Loss: 3.387568
# Epoch: 72 	 Validation precision@k5: 0.6901, accuracy@k5: 0.3711
# Epoch: 72 	 Validation precision@k10: 0.6545, accuracy@k10: 0.5630
# Epoch: 72 	 Validation precision@k15: 0.6853, accuracy@k15: 0.6662
# Epoch: 72 	 Validation precision@k20: 0.7433, accuracy@k20: 0.7415
# Epoch: 72 	 Validation precision@k25: 0.7972, accuracy@k25: 0.7971
# Epoch: 72 	 Validation precision@k30: 0.8376, accuracy@k30: 0.8376
# CPU: 21.29
# RAM %: 62.7
# Epoch: 73 	 Training Loss: 3.388022
# Epoch: 73 	 Validation precision@k5: 0.6870, accuracy@k5: 0.3685
# Epoch: 73 	 Validation precision@k10: 0.6503, accuracy@k10: 0.5596
# Epoch: 73 	 Validation precision@k15: 0.6856, accuracy@k15: 0.6666
# Epoch: 73 	 Validation precision@k20: 0.7430, accuracy@k20: 0.7412
# Epoch: 73 	 Validation precision@k25: 0.7980, accuracy@k25: 0.7979
# Epoch: 73 	 Validation precision@k30: 0.8400, accuracy@k30: 0.8400
# CPU: 21.14
# RAM %: 62.3
# Epoch: 74 	 Training Loss: 3.387979
# Epoch: 74 	 Validation precision@k5: 0.6975, accuracy@k5: 0.3747
# Epoch: 74 	 Validation precision@k10: 0.6584, accuracy@k10: 0.5669
# Epoch: 74 	 Validation precision@k15: 0.6852, accuracy@k15: 0.6660
# Epoch: 74 	 Validation precision@k20: 0.7451, accuracy@k20: 0.7432
# Epoch: 74 	 Validation precision@k25: 0.8001, accuracy@k25: 0.8000
# Epoch: 74 	 Validation precision@k30: 0.8377, accuracy@k30: 0.8377
# CPU: 21.15
# RAM %: 62.3
# Epoch: 75 	 Training Loss: 3.387162
# Epoch: 75 	 Validation precision@k5: 0.6990, accuracy@k5: 0.3760
# Epoch: 75 	 Validation precision@k10: 0.6562, accuracy@k10: 0.5648
# Epoch: 75 	 Validation precision@k15: 0.6847, accuracy@k15: 0.6655
# Epoch: 75 	 Validation precision@k20: 0.7424, accuracy@k20: 0.7405
# Epoch: 75 	 Validation precision@k25: 0.7981, accuracy@k25: 0.7980
# Epoch: 75 	 Validation precision@k30: 0.8403, accuracy@k30: 0.8403
# CPU: 21.15
# RAM %: 62.4
# Epoch: 76 	 Training Loss: 3.387185
# Epoch: 76 	 Validation precision@k5: 0.7007, accuracy@k5: 0.3776
# Epoch: 76 	 Validation precision@k10: 0.6571, accuracy@k10: 0.5655
# Epoch: 76 	 Validation precision@k15: 0.6885, accuracy@k15: 0.6693
# Epoch: 76 	 Validation precision@k20: 0.7443, accuracy@k20: 0.7425
# Epoch: 76 	 Validation precision@k25: 0.7990, accuracy@k25: 0.7989
# Epoch: 76 	 Validation precision@k30: 0.8372, accuracy@k30: 0.8372
# CPU: 21.07
# RAM %: 62.3
# Epoch: 77 	 Training Loss: 3.387359
# Epoch: 77 	 Validation precision@k5: 0.6998, accuracy@k5: 0.3757
# Epoch: 77 	 Validation precision@k10: 0.6537, accuracy@k10: 0.5623
# Epoch: 77 	 Validation precision@k15: 0.6862, accuracy@k15: 0.6672
# Epoch: 77 	 Validation precision@k20: 0.7470, accuracy@k20: 0.7452
# Epoch: 77 	 Validation precision@k25: 0.7977, accuracy@k25: 0.7976
# Epoch: 77 	 Validation precision@k30: 0.8381, accuracy@k30: 0.8381
# CPU: 20.90
# RAM %: 62.3
# Epoch: 78 	 Training Loss: 3.386833
# Epoch: 78 	 Validation precision@k5: 0.6952, accuracy@k5: 0.3739
# Epoch: 78 	 Validation precision@k10: 0.6521, accuracy@k10: 0.5611
# Epoch: 78 	 Validation precision@k15: 0.6847, accuracy@k15: 0.6654
# Epoch: 78 	 Validation precision@k20: 0.7441, accuracy@k20: 0.7422
# Epoch: 78 	 Validation precision@k25: 0.7978, accuracy@k25: 0.7977
# Epoch: 78 	 Validation precision@k30: 0.8358, accuracy@k30: 0.8358
# CPU: 20.93
# RAM %: 62.3
# Epoch: 79 	 Training Loss: 3.387355
# Epoch: 79 	 Validation precision@k5: 0.6924, accuracy@k5: 0.3718
# Epoch: 79 	 Validation precision@k10: 0.6546, accuracy@k10: 0.5632
# Epoch: 79 	 Validation precision@k15: 0.6856, accuracy@k15: 0.6665
# Epoch: 79 	 Validation precision@k20: 0.7424, accuracy@k20: 0.7406
# Epoch: 79 	 Validation precision@k25: 0.7997, accuracy@k25: 0.7996
# Epoch: 79 	 Validation precision@k30: 0.8390, accuracy@k30: 0.8390
# CPU: 20.66
# RAM %: 62.3
# Epoch: 80 	 Training Loss: 3.386858
# Epoch: 80 	 Validation precision@k5: 0.6867, accuracy@k5: 0.3688
# Epoch: 80 	 Validation precision@k10: 0.6541, accuracy@k10: 0.5631
# Epoch: 80 	 Validation precision@k15: 0.6862, accuracy@k15: 0.6670
# Epoch: 80 	 Validation precision@k20: 0.7416, accuracy@k20: 0.7397
# Epoch: 80 	 Validation precision@k25: 0.8000, accuracy@k25: 0.7999
# Epoch: 80 	 Validation precision@k30: 0.8386, accuracy@k30: 0.8386
# CPU: 20.49
# RAM %: 62.3
# Epoch: 81 	 Training Loss: 3.386675
# Epoch: 81 	 Validation precision@k5: 0.6900, accuracy@k5: 0.3715
# Epoch: 81 	 Validation precision@k10: 0.6580, accuracy@k10: 0.5662
# Epoch: 81 	 Validation precision@k15: 0.6856, accuracy@k15: 0.6665
# Epoch: 81 	 Validation precision@k20: 0.7419, accuracy@k20: 0.7400
# Epoch: 81 	 Validation precision@k25: 0.7962, accuracy@k25: 0.7961
# Epoch: 81 	 Validation precision@k30: 0.8387, accuracy@k30: 0.8387
# CPU: 20.65
# RAM %: 62.3
# Epoch: 82 	 Training Loss: 3.386542
# Epoch: 82 	 Validation precision@k5: 0.6839, accuracy@k5: 0.3682
# Epoch: 82 	 Validation precision@k10: 0.6519, accuracy@k10: 0.5607
# Epoch: 82 	 Validation precision@k15: 0.6831, accuracy@k15: 0.6640
# Epoch: 82 	 Validation precision@k20: 0.7429, accuracy@k20: 0.7411
# Epoch: 82 	 Validation precision@k25: 0.7964, accuracy@k25: 0.7963
# Epoch: 82 	 Validation precision@k30: 0.8373, accuracy@k30: 0.8373
# CPU: 20.45
# RAM %: 62.3
# Epoch: 83 	 Training Loss: 3.386464
# Epoch: 83 	 Validation precision@k5: 0.7033, accuracy@k5: 0.3785
# Epoch: 83 	 Validation precision@k10: 0.6525, accuracy@k10: 0.5615
# Epoch: 83 	 Validation precision@k15: 0.6861, accuracy@k15: 0.6670
# Epoch: 83 	 Validation precision@k20: 0.7420, accuracy@k20: 0.7401
# Epoch: 83 	 Validation precision@k25: 0.7981, accuracy@k25: 0.7980
# Epoch: 83 	 Validation precision@k30: 0.8384, accuracy@k30: 0.8384
# CPU: 20.46
# RAM %: 62.2
# Epoch: 84 	 Training Loss: 3.385565
# Epoch: 84 	 Validation precision@k5: 0.7030, accuracy@k5: 0.3774
# Epoch: 84 	 Validation precision@k10: 0.6578, accuracy@k10: 0.5660
# Epoch: 84 	 Validation precision@k15: 0.6865, accuracy@k15: 0.6672
# Epoch: 84 	 Validation precision@k20: 0.7425, accuracy@k20: 0.7406
# Epoch: 84 	 Validation precision@k25: 0.7976, accuracy@k25: 0.7975
# Epoch: 84 	 Validation precision@k30: 0.8380, accuracy@k30: 0.8380
# CPU: 20.63
# RAM %: 62.3
# Epoch: 85 	 Training Loss: 3.386330
# Epoch: 85 	 Validation precision@k5: 0.6970, accuracy@k5: 0.3738
# Epoch: 85 	 Validation precision@k10: 0.6562, accuracy@k10: 0.5645
# Epoch: 85 	 Validation precision@k15: 0.6881, accuracy@k15: 0.6688
# Epoch: 85 	 Validation precision@k20: 0.7440, accuracy@k20: 0.7421
# Epoch: 85 	 Validation precision@k25: 0.7979, accuracy@k25: 0.7978
# Epoch: 85 	 Validation precision@k30: 0.8371, accuracy@k30: 0.8371
# CPU: 20.57
# RAM %: 62.3
# Epoch: 86 	 Training Loss: 3.385695
# Epoch: 86 	 Validation precision@k5: 0.6943, accuracy@k5: 0.3733
# Epoch: 86 	 Validation precision@k10: 0.6540, accuracy@k10: 0.5627
# Epoch: 86 	 Validation precision@k15: 0.6892, accuracy@k15: 0.6698
# Epoch: 86 	 Validation precision@k20: 0.7454, accuracy@k20: 0.7435
# Epoch: 86 	 Validation precision@k25: 0.7980, accuracy@k25: 0.7979
# Epoch: 86 	 Validation precision@k30: 0.8388, accuracy@k30: 0.8388
# CPU: 20.41
# RAM %: 62.3
# Epoch: 87 	 Training Loss: 3.386289
# Epoch: 87 	 Validation precision@k5: 0.6926, accuracy@k5: 0.3727
# Epoch: 87 	 Validation precision@k10: 0.6578, accuracy@k10: 0.5660
# Epoch: 87 	 Validation precision@k15: 0.6863, accuracy@k15: 0.6672
# Epoch: 87 	 Validation precision@k20: 0.7425, accuracy@k20: 0.7407
# Epoch: 87 	 Validation precision@k25: 0.7987, accuracy@k25: 0.7986
# Epoch: 87 	 Validation precision@k30: 0.8378, accuracy@k30: 0.8378
# CPU: 20.28
# RAM %: 62.3
# Epoch: 88 	 Training Loss: 3.386551
# Epoch: 88 	 Validation precision@k5: 0.6968, accuracy@k5: 0.3761
# Epoch: 88 	 Validation precision@k10: 0.6563, accuracy@k10: 0.5650
# Epoch: 88 	 Validation precision@k15: 0.6881, accuracy@k15: 0.6689
# Epoch: 88 	 Validation precision@k20: 0.7406, accuracy@k20: 0.7387
# Epoch: 88 	 Validation precision@k25: 0.7975, accuracy@k25: 0.7974
# Epoch: 88 	 Validation precision@k30: 0.8377, accuracy@k30: 0.8377
# CPU: 20.28
# RAM %: 62.3
# Epoch: 89 	 Training Loss: 3.385464
# Epoch: 89 	 Validation precision@k5: 0.6910, accuracy@k5: 0.3710
# Epoch: 89 	 Validation precision@k10: 0.6553, accuracy@k10: 0.5641
# Epoch: 89 	 Validation precision@k15: 0.6863, accuracy@k15: 0.6671
# Epoch: 89 	 Validation precision@k20: 0.7431, accuracy@k20: 0.7413
# Epoch: 89 	 Validation precision@k25: 0.7986, accuracy@k25: 0.7986
# Epoch: 89 	 Validation precision@k30: 0.8399, accuracy@k30: 0.8399
# CPU: 20.59
# RAM %: 62.3
# Epoch: 90 	 Training Loss: 3.386713
# Epoch: 90 	 Validation precision@k5: 0.7063, accuracy@k5: 0.3797
# Epoch: 90 	 Validation precision@k10: 0.6573, accuracy@k10: 0.5657
# Epoch: 90 	 Validation precision@k15: 0.6895, accuracy@k15: 0.6702
# Epoch: 90 	 Validation precision@k20: 0.7422, accuracy@k20: 0.7403
# Epoch: 90 	 Validation precision@k25: 0.7950, accuracy@k25: 0.7949
# Epoch: 90 	 Validation precision@k30: 0.8350, accuracy@k30: 0.8350
# CPU: 20.87
# RAM %: 62.3
# Epoch: 91 	 Training Loss: 3.385465
# Epoch: 91 	 Validation precision@k5: 0.6969, accuracy@k5: 0.3748
# Epoch: 91 	 Validation precision@k10: 0.6544, accuracy@k10: 0.5634
# Epoch: 91 	 Validation precision@k15: 0.6876, accuracy@k15: 0.6682
# Epoch: 91 	 Validation precision@k20: 0.7431, accuracy@k20: 0.7413
# Epoch: 91 	 Validation precision@k25: 0.7964, accuracy@k25: 0.7963
# Epoch: 91 	 Validation precision@k30: 0.8350, accuracy@k30: 0.8350
# CPU: 21.34
# RAM %: 62.3
# Epoch: 92 	 Training Loss: 3.385214
# Epoch: 92 	 Validation precision@k5: 0.6926, accuracy@k5: 0.3726
# Epoch: 92 	 Validation precision@k10: 0.6537, accuracy@k10: 0.5620
# Epoch: 92 	 Validation precision@k15: 0.6843, accuracy@k15: 0.6651
# Epoch: 92 	 Validation precision@k20: 0.7421, accuracy@k20: 0.7403
# Epoch: 92 	 Validation precision@k25: 0.7972, accuracy@k25: 0.7971
# Epoch: 92 	 Validation precision@k30: 0.8385, accuracy@k30: 0.8385
# CPU: 21.24
# RAM %: 62.2
# Epoch: 93 	 Training Loss: 3.384837
# Epoch: 93 	 Validation precision@k5: 0.6916, accuracy@k5: 0.3719
# Epoch: 93 	 Validation precision@k10: 0.6533, accuracy@k10: 0.5620
# Epoch: 93 	 Validation precision@k15: 0.6842, accuracy@k15: 0.6650
# Epoch: 93 	 Validation precision@k20: 0.7398, accuracy@k20: 0.7379
# Epoch: 93 	 Validation precision@k25: 0.7959, accuracy@k25: 0.7958
# Epoch: 93 	 Validation precision@k30: 0.8363, accuracy@k30: 0.8363
# CPU: 21.38
# RAM %: 62.2
# Epoch: 94 	 Training Loss: 3.385198
# Epoch: 94 	 Validation precision@k5: 0.6919, accuracy@k5: 0.3716
# Epoch: 94 	 Validation precision@k10: 0.6558, accuracy@k10: 0.5644
# Epoch: 94 	 Validation precision@k15: 0.6843, accuracy@k15: 0.6652
# Epoch: 94 	 Validation precision@k20: 0.7437, accuracy@k20: 0.7418
# Epoch: 94 	 Validation precision@k25: 0.7995, accuracy@k25: 0.7994
# Epoch: 94 	 Validation precision@k30: 0.8369, accuracy@k30: 0.8369
# CPU: 21.32
# RAM %: 62.3
# Epoch: 95 	 Training Loss: 3.385265
# Epoch: 95 	 Validation precision@k5: 0.7066, accuracy@k5: 0.3799
# Epoch: 95 	 Validation precision@k10: 0.6547, accuracy@k10: 0.5633
# Epoch: 95 	 Validation precision@k15: 0.6845, accuracy@k15: 0.6652
# Epoch: 95 	 Validation precision@k20: 0.7407, accuracy@k20: 0.7388
# Epoch: 95 	 Validation precision@k25: 0.7985, accuracy@k25: 0.7984
# Epoch: 95 	 Validation precision@k30: 0.8388, accuracy@k30: 0.8388
# CPU: 21.24
# RAM %: 62.3
# Epoch: 96 	 Training Loss: 3.384497
# Epoch: 96 	 Validation precision@k5: 0.6950, accuracy@k5: 0.3742
# Epoch: 96 	 Validation precision@k10: 0.6574, accuracy@k10: 0.5657
# Epoch: 96 	 Validation precision@k15: 0.6847, accuracy@k15: 0.6657
# Epoch: 96 	 Validation precision@k20: 0.7452, accuracy@k20: 0.7434
# Epoch: 96 	 Validation precision@k25: 0.8005, accuracy@k25: 0.8004
# Epoch: 96 	 Validation precision@k30: 0.8387, accuracy@k30: 0.8387
# CPU: 21.36
# RAM %: 62.3
# Epoch: 97 	 Training Loss: 3.385555
# Epoch: 97 	 Validation precision@k5: 0.6955, accuracy@k5: 0.3751
# Epoch: 97 	 Validation precision@k10: 0.6552, accuracy@k10: 0.5636
# Epoch: 97 	 Validation precision@k15: 0.6848, accuracy@k15: 0.6655
# Epoch: 97 	 Validation precision@k20: 0.7423, accuracy@k20: 0.7405
# Epoch: 97 	 Validation precision@k25: 0.7984, accuracy@k25: 0.7983
# Epoch: 97 	 Validation precision@k30: 0.8364, accuracy@k30: 0.8364
# CPU: 21.24
# RAM %: 62.1
# Epoch: 98 	 Training Loss: 3.385049
# Epoch: 98 	 Validation precision@k5: 0.7010, accuracy@k5: 0.3770
# Epoch: 98 	 Validation precision@k10: 0.6543, accuracy@k10: 0.5632
# Epoch: 98 	 Validation precision@k15: 0.6869, accuracy@k15: 0.6676
# Epoch: 98 	 Validation precision@k20: 0.7430, accuracy@k20: 0.7411
# Epoch: 98 	 Validation precision@k25: 0.7968, accuracy@k25: 0.7967
# Epoch: 98 	 Validation precision@k30: 0.8382, accuracy@k30: 0.8382
# CPU: 21.46
# RAM %: 62.2
# Epoch: 99 	 Training Loss: 3.385540
# Epoch: 99 	 Validation precision@k5: 0.6957, accuracy@k5: 0.3732
# Epoch: 99 	 Validation precision@k10: 0.6539, accuracy@k10: 0.5626
# Epoch: 99 	 Validation precision@k15: 0.6857, accuracy@k15: 0.6665
# Epoch: 99 	 Validation precision@k20: 0.7412, accuracy@k20: 0.7394
# Epoch: 99 	 Validation precision@k25: 0.7995, accuracy@k25: 0.7994
# Epoch: 99 	 Validation precision@k30: 0.8380, accuracy@k30: 0.8380
# CPU: 21.38
# RAM %: 62.3
# Epoch: 100 	 Training Loss: 3.384565
# Epoch: 100 	 Validation precision@k5: 0.6971, accuracy@k5: 0.3744
# Epoch: 100 	 Validation precision@k10: 0.6511, accuracy@k10: 0.5606
# Epoch: 100 	 Validation precision@k15: 0.6865, accuracy@k15: 0.6674
# Epoch: 100 	 Validation precision@k20: 0.7428, accuracy@k20: 0.7409
# Epoch: 100 	 Validation precision@k25: 0.7966, accuracy@k25: 0.7965
# Epoch: 100 	 Validation precision@k30: 0.8389, accuracy@k30: 0.8389
# CPU: 21.38
# RAM %: 62.3
# Max CPU usage: 21.463	Max RAM % usage: 62.7
# CPU times: user 39min 15s, sys: 10min 48s, total: 50min 3s
# Wall time: 37min 52s

# %%
for k in range(5, 31, 5):
    precision_k, accuracy_k = eval_model(enhanced_retain, test_loader, k=k)
    print(f'Validation precision@k{k}: {precision_k:.4f}, accuracy@k{k}: {accuracy_k:.4f}')
# Out:
# Validation precision@k5: 0.6896, accuracy@k5: 0.3794
# Validation precision@k10: 0.6472, accuracy@k10: 0.5581
# Validation precision@k15: 0.6867, accuracy@k15: 0.6666
# Validation precision@k20: 0.7440, accuracy@k20: 0.7409
# Validation precision@k25: 0.7936, accuracy@k25: 0.7934
# Validation precision@k30: 0.8325, accuracy@k30: 0.8325

# %%
torch.save(enhanced_retain, os.path.join(CHECKPOINT_PATH, "EnhancedRETAIN_100.pth"))
